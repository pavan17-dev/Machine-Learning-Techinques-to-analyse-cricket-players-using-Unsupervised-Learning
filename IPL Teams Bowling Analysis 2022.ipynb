# %%
# importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# importing dataset
bowling = pd.read_csv("ipl_2022_teams_bat_and_ball.csv")

# %%
bowling.head()
# Out:
#    S.No Team   M   I      R      B  Outs    Avg      SR   HS  ...    W  Econ  \
# 0     1   RR  17  17  2,807  2,025    97  28.94  138.62  222  ...  104  8.51
# 1     2   GT  16  16  2,517  1,895    82  30.70  132.82  199  ...  101  8.24
# 2     3  RCB  16  16  2,454  1,868    98  25.04  131.37  207  ...   97  8.63
# 3     4  LSG  15  15  2,405  1,758    89  27.02  136.80  211  ...  100  8.48
# 4     5   DC  14  14  2,218  1,582    81  27.38  140.20  215  ...   88  8.61
#
#    Bowling Avg  Bowling SR  fours given  sixs given dots  BP4G   BP6G  BPBG
# 0        27.23       19.19          241         113  770  8.28  17.66  5.64
# 1        25.09       18.28          218         101  716  8.47  18.28  5.79
# 2        26.95       18.73          183         147  727  9.93  12.36  5.51
# 3        24.96       17.65          233          94  698  7.58  18.78  5.40
# 4        27.24       18.99          206         103  617  8.11  16.22  5.41
#
# [5 rows x 28 columns]

# %%
colors = []
# Iterate over rows of ipl_bowlers
for idx, row in bowling.iterrows():
    if row['Team'] == "CSK" :
        colors.append('yellow')
    elif row['Team'] == "RCB" :
        colors.append('green')
    elif row['Team'] == "RR" :
        colors.append('deeppink')
    elif row["Team"] == "DC":
        colors.append('royalblue')
    elif row["Team"] == "GT":
        colors.append("mediumpurple")
    elif row["Team"] == 'PBKS':
        colors.append('red')
    elif row["Team"] == "KKR":
        colors.append('purple')
    elif row["Team"] == "LSG":
        colors.append('skyblue')
    elif row["Team"] == "SRH":
        colors.append("orange")
    elif row["Team"] == "MI":
        colors.append('blue')
    else:
        colors.append('black')
print(colors)
# Out:
# ['deeppink', 'mediumpurple', 'green', 'skyblue', 'royalblue', 'red', 'yellow', 'purple', 'blue', 'orange']

# %%
# finding the highest strike rate team in batting
# creating bar plot
fig = plt.figure(figsize=(17,9))
x = bowling["Team"]
y = bowling["SR"]
plt.bar(x,y,color=colors,width = 0.8)
plt.title("Batting Strike rate of the teams ipl 2022")
plt.xlabel("Name of the Team")
plt.ylabel("Batting Strike rate of Teams")
plt.show()

# %%
# finding the highest strike rate team in batting
# creating bar plot
fig = plt.figure(figsize=(17,9))
x = bowling["Team"]
y = bowling["Bowling SR"]
plt.bar(x,y,color=colors,width = 0.8)
plt.title("Bowling Strike rate of the teams ipl 2022")
plt.xlabel("Name of the Team")
plt.ylabel("Bowling Strike rate of Teams")
plt.show()

# %%
colors = []
# Iterate over rows of ipl_bowlers
for idx, row in bowling.iterrows():
    if row['Team'] == "CSK" :
        colors.append('yellow')
    elif row['Team'] == "RCB" :
        colors.append('green')
    elif row['Team'] == "RR" :
        colors.append('deeppink')
    elif row["Team"] == "DC":
        colors.append('royalblue')
    elif row["Team"] == "GT":
        colors.append("mediumpurple")
    elif row["Team"] == 'PBKS':
        colors.append('red')
    elif row["Team"] == "KKR":
        colors.append('purple')
    elif row["Team"] == "LSG":
        colors.append('skyblue')
    elif row["Team"] == "SRH":
        colors.append("orange")
    elif row["Team"] == "MI":
        colors.append('blue')
    else:
        colors.append('black')
print(colors)
# Out:
# ['deeppink', 'mediumpurple', 'green', 'skyblue', 'royalblue', 'red', 'yellow', 'purple', 'blue', 'orange']

# %%
# create scatter plot for left arm pacers on there economy and strikerate
fig = plt.figure(figsize=(12,4))
x = bowling["Bowling SR"]
y = bowling["SR"]
plt.scatter(x,y,c=colors,s=100)
plt.title("Bowling Strike Rate and Bowling Strike Rate of of teams in ipl 2022")
plt.xlabel("Bowling Strike Rate of the team")
plt.ylabel("Batting Strike Rate of the team")
for i, label in enumerate(bowling['Team']):
    plt.annotate(label,(x[i], y[i]))
plt.show()

# %%
# create scatter plot for left arm pacers on there economy and strikerate
fig = plt.figure(figsize=(12,4))
x = bowling["BP6"]
y = bowling["BP6G"]
plt.scatter(x,y,c=colors,s=100)
plt.title("Balls Per Six Vs Balls Per Six Given of teams in ipl 2022")
plt.xlabel("Balls Per Six of batting")
plt.ylabel("Balls Per Six Given")
for i, label in enumerate(bowling['Team']):
    plt.annotate(label,(x[i], y[i]))
plt.show()

# %%
# create scatter plot for teams on there BPB Scored and BPB Given
fig = plt.figure(figsize=(8,4))
x = bowling["BPB"]
y = bowling["BPBG"]
plt.scatter(x,y,c=colors,s=100)
plt.title("Balls Per Boundary Vs Balls Per Boundary Given of teams in ipl 2022")
plt.xlabel("Balls Per Boundary Scored")
plt.ylabel("Balls Per Boundary Given")
for i, label in enumerate(bowling['Team']):
    plt.annotate(label,(x[i], y[i]))
plt.show()
